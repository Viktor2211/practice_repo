# %%
import requests
headers = {
    "Authorization": "Bearer 9f78d682956360a7b6b7206567e20c6c",
    "Accept": "application/json"
}
response = requests.get('https://app.potok.io/api/v3/cursor_paginated/jobs.json', headers=headers)
raw = response.json()
raw
# Out:
# {'objects': {'jobs': [{'id': 1417561,
#     'name': 'Compliance officer',
#     'description': '<p style="margin:4px 0;"><span style="font-family:Arial, sans-serif;font-size:22px;white-space:normal;">Уровень знания узбекского и русского языка – 100%;</span><span style="font-family:Arial, sans-serif;font-size:22px;white-space:normal;">Открытость к фидбэкам;</span><span style="font-family:Arial, sans-serif;font-size:22px;white-space:normal;">Честность и скромность;</span><span style="font-family:Arial, sans-serif;font-size:22px;white-space:normal;">Ответственность и пунктуальность;</span><span style="font-family:Arial, sans-serif;font-size:22px;white-space:normal;">Усердие в саморазвитии и в работе.</span></p>',
#     'schedule_type': 'fullDay',
#     'salary_from': None,
#     'salary_to': None,
#     'code': None,
#     'code_enable': False,
#     'experience_type': 'noExperience',
#     'employment_type': 'full',
#     'currency_type': 'UZS',
#     'key_skills': [],
# ...
